# %%
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
dt = fits.open("../test/gspice-unit-test-desi.fits")

# %%
dt.info()
# Out:
# Filename: ../test/gspice-unit-test-desi.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       9   (2326, 2326)   float64
#   1                1 ImageHDU         7   (2326, 5000)   uint8

# %%
dt[0].header
# Out:
# SIMPLE  =                    T / Written by IDL:  Fri Dec 10 16:03:24 2021
# BITPIX  =                  -64 / Number of bits per data pixel
# NAXIS   =                    2 / Number of data axes
# NAXIS1  =                 2326 /
# NAXIS2  =                 2326 /
# EXTEND  =                    T / FITS data may contain extensions
# DATE    = '2021-12-10'         / Creation UTC (CCCC-MM-DD) date of FITS header
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode 2001A&A...376..359H

# %%
plt.plot(dt[0].data[0])

# %%
plt.figure(figsize = (10, 8))
plt.imshow(dt[0].data, cmap = 'magma')

# %%
import numpy as np

# %%
np.linalg.eigvals(dt[0].data).shape
# Out:
# (2326,)

# %%
dt[0].data.shape[0]
# Out:
# 2326

# %%
imask = np.array([0,0,0,1,1,0,0,0])

# %%
~imask
# Out:
# array([-1, -1, -1, -2, -2, -1, -1, -1])

# %%
imask = imask.astype(bool)
imask
# Out:
# array([False, False, False,  True,  True, False, False, False])

# %%
~imask
# Out:
# array([ True,  True,  True, False, False,  True,  True,  True])

# %%
np.where(~imask)[0]
# Out:
# array([0, 1, 2, 5, 6, 7])

# %%
mat = np.array([[3, 2, 1], [1, 3, 2], [2, 1, 0]])

# %%
np.linalg.inv(mat)
# Out:
# array([[ 0.66666667, -0.33333333, -0.33333333],
#        [-1.33333333,  0.66666667,  1.66666667],
#        [ 1.66666667, -0.33333333, -2.33333333]])

# %%
# Out:
# array([[3, 2, 1],
#        [1, 3, 2],
#        [2, 1, 0]])
