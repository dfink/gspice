# %% [markdown]
# Test GSPICE with synthetic stellar spectra from the `Payne`. These spectra were generated at BOSS resolution. Four parameters were varied:
# - $\log g$
# - $T_{\rm eff}$
# - Fe/H
# - $\alpha$ abundance

# %%
import h5py

import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
th5 = h5py.File("/global/cscratch1/sd/tanveerk/mocks.h5", 'r')
wv = th5['wavelength'][:]
params = th5['parameters'][:]
#spec = th5['spec'][:]

# %%
for i in range(1):
    plt.plot(wv, th5['spec/' + str(i) + '/flux'][:], alpha = 0.5)

# %%
Teff, log(g), [Fe/H], [alpha/Fe]

# %%
plt.hist(th5['parameters'][:,1])
# Out:
# (array([ 1699.,  5395., 13704., 28317., 47597., 67041., 75608., 71478.,
#         54797., 34364.]),
#  array([1.00033984, 1.45030457, 1.9002693 , 2.35023403, 2.80019876,
#         3.25016349, 3.70012822, 4.15009295, 4.60005768, 5.05002242,
#         5.49998715]),
#  <a list of 10 Patch objects>)

# %%
th5['parameters'][1]
# Out:
# array([ 5.38532114e+03,  3.10049266e+00, -6.31082716e-01,  3.00224452e-01])

# %%
Import h5py
th5 = h5py.File(‘mocks.h5’,’r’)
flux = th5[’spec/0/flux’][:]
